# %% [markdown]
# ## Import Libraries
# In order to generate a bag of words representation we need the following libraries

# %%
import numpy as np
import json

# %% [markdown]
# ## Import Data

# %%
# data_set = np.array([ [x['venue'], x['citations']] for x in json.load(open('train-1.json'))[:3] if x['venue']])
data_set = np.array([ [x['venue'], x['citations']] for x in json.load(open('train-1.json')) if x['venue']])
# print(data_set[0])

# %% [markdown]
# ## Proportion analysis of journals/venues
# Aim of the code is to divide the data in n equal portions, where the 'lowest' division accounts for the group of X that contributes the least to a given Y.

# %%
def divide_data_in_portions(XY, proportion=4):
    #split data
    XY_split = np.split(XY, 2, 1)
    Y = XY_split[1].astype(np.int16)
    
    summed_Y = np.sum(Y)
    print('There are in total', summed_Y, 'citations in this data')    
    unique_X = np.unique(XY_split[0],return_counts=True)
    print('Found',len(unique_X[0]), 'unique variables')
    # average_contribution = summed_Y / len(unique_X[0])

    a = np.zeros((3,len(unique_X[0])))
    c = [unique_X[0], unique_X[1].astype(int), a[0].astype(int), a[1].astype(int), a[2].astype(float)]
    for x in XY :
        c[2][np.where(c[0] == x[0])[0][0]] += int(x[1])
        # new_count = int(c[2][np.where(c[0] == x[0])[0][0]]) + x[1]
        # c[2][np.where(c[0] == x[0])[0][0]] = new_count
    for (i, j) in enumerate(c[3]):
        c[3][i] = (c[2][i]/c[1][i])
        c[4][i] = 100/summed_Y*c[2][i]
    return c
    

division = divide_data_in_portions(data_set)
sorted_division = np.sort(division[3])

print (division)
# Out:
# There are in total 353556 citations in this data
# Found 299 unique variables
# [array(['*SEM', '*SEM@NAACL-HLT', '*SEMEVAL', 'ACL', 'ACL 1979',
#        'ACL 1984', 'ACL 1996', 'ACL 1999', 'ACL 2000', 'ACL 2002',
#        'ACL 2003', 'ACL 2011', 'ACL 2014', 'ACL 2015', 'ACL 2016',
#        'ACL 2018', 'ACL 2019', 'ACL 2020',
#        'ACL Workshop on Natural Language Processing in the Biomedical Domain',
#        'ACL/IJCNLP', 'AKBC@NAACL-HLT', 'ALVR', 'ALW', 'ALW@ACL',
#        'AMERICASNLP', 'ANLP', 'ANLP@ACL', 'ANLP@EMNLP', 'AUTOSIMTRANS',
#        'ArXiv', 'ArgMining@ACL', 'ArgMining@EMNLP', 'ArgMining@HLT-NAACL',
#        'BEA', 'BEA@ACL', 'BEA@EMNLP', 'BEA@NAACL-HLT', 'BIONLP',
#        'BLACKBOXNLP', 'BPPF', 'BSNLP@ACL', 'BSNLP@EACL', 'BUCC@ACL',
#        'BUCC@ACL/IJCNLP', 'BioNLP', 'BioNLP-OST@EMNLP-IJNCLP',
#        'BioNLP@ACL', 'BioNLP@IJCNLP', 'BiomedicalNLP@RANLP',
#        'BlackboxNLP@ACL', 'BlackboxNLP@EMNLP', 'CALCS', 'CASE', 'CC-NLG',
#        'CIPS-SIGHAN', 'CL', 'CLINICALNLP', 'CLPSYCH', 'CLPsych@ACL',
#        'CLPsych@HLT-NAACL', 'CLPsych@NAACL-HTL', 'CLfL@EACL',
#        'CLfL@NAACL-HLT', 'CMCL', 'CMCL@ACL', 'CMCL@EACL',
#        'CMCL@NAACL-HLT', 'CODI', 'COLING', 'COLING 2014', 'COLING-ACL',
#        'CONLL', 'CORBON@HLT-NAACL', 'CVSC@EACL', 'CoNLL', 'CoNLL 2010',
#        'CoNLL Shared Task', 'CodeSwitch@ACL', 'CodeSwitch@EMNLP',
#        'CogALex@COLING', 'Comput. Linguistics',
#        'Computational Linguistics', 'DASH', 'DEELIO', 'DIALDOC',
#        'DM@EACL', 'DeepLo@ACL', 'DeepLo@EMNLP-IJCNLP', 'DiscoMT@EMNLP',
#        'EACL', 'EACL 2014', 'ECNLP', 'ECONLP@ACL', 'EMNLP', 'EMNLP 2014',
#        'EMNLP 2015', 'EMNLP 2016', 'EMNLP 2017', 'EMNLP 2018',
#        'EMNLP 2019', 'EMNLP 2020', 'EMNLP-IJCNLP', 'EMNLP/IJCNLP', 'ENLG',
#        'EVAL4NLP', 'EVENTS@ACL', 'EVENTS@HLP-NAACL', 'EVENTS@HLT-NAACL',
#        'Encyclopedia of Data Warehousing and Mining', 'EthNLP@EACL',
#        'EthNLP@NAACL-HLT', 'FEVER', 'FIGLANG', 'FINDINGS', 'FSMNLP',
#        'Fig-Lang@ACL', 'Fig-Lang@NAACL-HLT', 'GEBNLP', 'GEM', 'HLT',
#        'HLT-NAACL', 'HLT-NAACL Demos', 'HRI 2018', 'HaCaT@EACL',
#        'HyTra@ACL', 'HyTra@EACL', 'IIR', 'IJCAI', 'IJCNLP', 'IJCNLP 2015',
#        'INLG', 'INSIGHTS', 'INTERNLP', 'INTERSPEECH', 'INTEXSEMPAR',
#        'IWCS', 'IWP@ACL', 'IWPT', 'IWSLT', 'J. Chin. Lang. Comput.',
#        'LAW@ACL', 'LAW@COLING', 'LAW@NAACL-HLT', 'LCHANGE', 'LDL@IJCNLP',
#        'LG-LP@COLING', 'LOUHI', 'LOUHI@EMNLP', 'LREC', 'LSDSem@EACL',
#        'LSDSem@EMNLP', 'LTCSS@ACL', 'LaTeCH@ACL', 'LaTeCH@EACL',
#        'LaTeCH@NAACL-HLT', 'Louhi@EACL', 'Louhi@EMNLP', 'MAIWORKSHOP',
#        'METANLP', 'MOL', 'MRQA@EMNLP', 'MSR@EMNLP-IJCNLP', 'MWE',
#        'MWE-WN@ACL', 'MWE@ACL', 'MWE@EACL', 'MWE@NAACL-HLT',
#        'MultiLing@EACL', 'NAACL', 'NAACL 2015', 'NAACL 2016',
#        'NAACL 2018', 'NAACL 2019', 'NAACL-HLT', 'NER@ACL', 'NEWS@ACL',
#        'NEWS@ACM', 'NFiS@EMNLP', 'NGT', 'NGT@EMNLP-IJCNLP', 'NLI',
#        'NLP+CSS@ACL', 'NLP+CSS@EMNLP', 'NLP-TEA@ACL',
#        'NLP-TEA@ACL/IJCNLP', 'NLP4CONVAI', 'NLP4COVID@EMNLP', 'NLP4IF',
#        'NLP4POSIMPACT', 'NLP4PROG', 'NLPBT', 'NLPCSS', 'NLPMC', 'NLPOSS',
#        'NLPmJ@EMNLP', 'NMT@ACL', 'NUSE', 'NUT@EMNLP', 'NUT@IJCNLP',
#        'OIAF4HLT@COLING', 'PACLIC', 'PEOPLES@NAACL-HTL', 'PITR@EACL',
#        'PRIVATENLP',
#        'Proceedings of the 59th Annual Meeting of the Association for Computational Linguistics and the 11th International Joint Conference on Natural Language Processing: System Demonstrations',
#        'Proceedings of the 59th Annual Meeting of the Association for Computational Linguistics and the 11th International Joint Conference on Natural Language Processing: Tutorial Abstracts',
#        'Proceedings of the First Workshop on Computational Approaches to Discourse',
#        'Proceedings of the Second Workshop Human-Informed Translation and Interpreting Technology associated with RANLP 2019',
#        'Proceedings of the conference. Association for Computational Linguistics. Meeting',
#        'Proceedings of the conference. Association for Computational Linguistics. North American Chapter. Meeting',
#        'QA@ACL', 'RANLP', 'RANLP 2017', 'REPL4NLP', 'Rep4NLP@ACL',
#        'RepEval@ACL', 'RepEval@EMNLP', 'RepL4NLP@ACL', 'RoboNLP@ACL',
#        'SCAI', 'SCAI@EMNLP', 'SCIL', 'SCNLP@EMNLP 2017', 'SDP', 'SEMEVAL',
#        'SEMITIC@ACL', 'SENSEVAL', 'SENSEVAL@ACL', 'SIGDIAL 2015',
#        'SIGDIAL Conference', 'SIGDIAL Workshop', 'SIGHAN',
#        'SIGHAN@IJCNLP', 'SIGMORPHON', 'SIGMORPHON/SIGFSM', 'SIGTYP',
#        'SIGdial', 'SLPAT@ACL', 'SLPAT@Interspeech', 'SMM4H', 'SOCIALNLP',
#        'SPLU', 'SPLUROBONLP', 'SPNLP', 'SPNLP@EMNLP', 'SPNLP@NAACL-HLT',
#        'SSST@EMNLP', 'SSST@NAACL-HLT', 'STARSEM', 'SUSTAINLP',
#        'SWAIE@COLING', 'SWCN@EMNLP', 'SedMT@NAACL-HLT', 'SemEval@ACL',
#        'SemEval@COLING', 'SemEval@NAACL-HLT', 'SocialNLP@ACL',
#        'SocialNLP@COLING', 'SocialNLP@EACL', 'SocialNLP@EMNLP',
#        'SocialNLP@NAACL', 'Speech-to-Speech Translation@ACL', 'TACL',
#        'TEACHINGNLP', 'TEXTGRAPHS', 'TIPSTER', 'TLT', 'TRUSTNLP',
#        'TextGraphs@ACL', 'TextGraphs@EMNLP', 'TextGraphs@NAACL-HLT',
#        'Transactions of the Association for Computational Linguistics',
#        'UDW@EMNLP', 'UNIMPLICIT', 'VL@ACL', 'VL@COLING', 'VL@EACL',
#        'VL@EMNLP', 'VS@HLT-NAACL', 'VarDial', 'VarDial@COLING',
#        'ViGIL@NeurIPS', 'W-NUT@EMNLP', 'WAC@ACL', 'WANLP@ACL 2019',
#        'WANLP@EACL', 'WASSA@ACL', 'WASSA@EMNLP', 'WASSA@NAACL-HLT', 'WAT',
#        'WAT@EMNLP-IJCNLP', 'WINLP', 'WMT', 'WMT@ACL', 'WMT@EMNLP', 'WNUT',
#        'WOAH', 'WSSANLP@COLING', 'WaC@EACL'], dtype='<U185'), array([  10,    2,  432, 1947,    1,    1,    2,    1,    8,   13,   14,
#           1,    9,    2,    2,    1,    2,    1,    7,  280,    6,    7,
#          21,    7,   15,  105,    6,   15,    6,   79,   31,   14,    5,
#           5,   26,   17,   44,   24,    9,    3,    5,    8,    5,    7,
#          38,   10,   51,   10,    3,   13,   22,    9,    9,    5,   15,
#         106,   13,    8,    8,   17,   10,    2,    7,   13,    3,    2,
#           5,    6,  284,    5,   95,   18,    4,    2,  159,    1,   23,
#           7,   11,    9,    1,  113,    8,    5,    4,    9,    3,   12,
#          22,   60,    4,   14,    2, 1145,    4,    1,    2,    2,   10,
#           1,    6,    1,  174,   10,    8,    6,    7,    1,    1,    7,
#           1,    4,   18,  352,    6,    1,    9,    5,   11,    4,    2,
#           1,    1,    6,    4,    7,    1,    1,   26,    3,  116,    7,
#           2,    1,    2,   14,    8,   30,   27,    1,   23,    7,    6,
#           4,    5,   11,    7,    5,    1,    4,    3,    9,   28,    9,
#           3,    4,   22,    3,    2,    8,   12,    3,    4,    8,    6,
#          20,    4,    6,  780,    2,    4,    1,    2,    6,    2,   14,
#           6,    5,    7,    9,    3,    7,    7,   10,    5,    2,   18,
#          10,    5,    3,    4,   10,   10,    9,    7,    9,   12,   23,
#           9,    7,    2,    8,    5,    4,   10,    2,    1,    8,    1,
#           1,    6,  100,    2,   20,   37,   11,    2,   12,    6,    3,
#           6,    2,    3,   22,   77,    5,    7,    1,    1,   79,   21,
#           7,   14,   32,    1,   11,   29,    2,   13,   12,    9,    1,
#           5,    5,    2,    2,    8,    6,   16,   14,    3,    7,    2,
#          68,    1,    6,    8,    3,    2,    4,    2,    7,   44,    5,
#           2,   47,    4,    1,    5,    9,    7,   79,    4,    3,    4,
#           8,    4,    5,    9,    9,    4,    2,   26,    9,   15,   10,
#          11,   40,   15,   10,   11,   12,  172,   19,   21,   27,   11,
#           6,    1]), array([    88,     21,   8783, 141182,      0,      3,      4,      5,
#           105,    894,    815,      2,    179,     14,     22,      3,
#             2,      2,    276,    665,     59,      6,    378,    803,
#             6,   7234,     31,    381,     23,   1634,    738,    133,
#           179,     32,    280,    218,    897,     63,     54,      0,
#            72,     31,     28,     44,    594,     52,    853,    198,
#            10,    261,   2445,     13,     16,     16,     85,  11873,
#            22,      2,    140,    620,    206,     80,     83,     94,
#            10,     12,     51,      7,   1370,     25,   3373,     71,
#            16,     33,   5500,     23,    498,     68,    341,     30,
#            41,   8414,      1,      0,      3,     31,     18,    101,
#           232,   1877,     18,     17,     17,  64578,    252,     14,
#             4,    387,    183,    144,     72,     26,   4770,     73,
#            30,     99,    137,      2,      5,    250,      5,     26,
#            83,   1391,     19,      4,     45,      1,     42,    368,
#            80,     28,      2,     78,     22,     23,      4,    169,
#           535,      6,   1490,     13,      1,      8,      1,     58,
#           405,    120,    126,     13,    172,     77,    103,      1,
#            30,     91,     10,     16,      0,    101,     13,    329,
#           184,     30,     11,     28,    219,      2,      0,     64,
#           192,     10,      1,     24,     34,    118,     59,     94,
#         33845,     13,    262,      0,     43,    636,     42,    120,
#           108,     45,     24,    119,      2,     72,    404,     49,
#            62,     58,    102,     17,      1,      2,      6,     16,
#            26,     18,     94,    977,     25,    202,    299,     23,
#            51,     62,    153,      1,     18,      0,      1,      6,
#             0,      2,    255,    660,     12,     42,   1282,    294,
#            21,    129,     37,      5,     70,     78,     15,     37,
#           108,    472,    130,     75,      0,   2453,    322,    703,
#            52,    491,      0,     14,    414,      4,     88,     14,
#            44,      2,      0,      8,      3,     23,   3659,     13,
#            10,     43,     14,    114,     12,    744,     83,    362,
#           130,     90,      7,     22,     17,     93,   3992,      0,
#             2,    531,      3,      0,     32,     70,    117,   4538,
#            60,      2,    236,     18,     12,    198,    491,    128,
#            34,     50,    130,    124,    229,    185,    217,    444,
#           138,      0,     25,      6,   4104,    230,    789,     91,
#             2,     20,     77]), array([  8,  10,  20,  72,   0,   3,   2,   5,  13,  68,  58,   2,  19,
#          7,  11,   3,   1,   2,  39,   2,   9,   0,  18, 114,   0,  68,
#          5,  25,   3,  20,  23,   9,  35,   6,  10,  12,  20,   2,   6,
#          0,  14,   3,   5,   6,  15,   5,  16,  19,   3,  20, 111,   1,
#          1,   3,   5, 112,   1,   0,  17,  36,  20,  40,  11,   7,   3,
#          6,  10,   1,   4,   5,  35,   3,   4,  16,  34,  23,  21,   9,
#         31,   3,  41,  74,   0,   0,   0,   3,   6,   8,  10,  31,   4,
#          1,   8,  56,  63,  14,   2, 193,  18, 144,  12,  26,  27,   7,
#          3,  16,  19,   2,   5,  35,   5,   6,   4,   3,   3,   4,   5,
#          0,   3,  92,  40,  28,   2,  13,   5,   3,   4, 169,  20,   2,
#         12,   1,   0,   8,   0,   4,  50,   4,   4,  13,   7,  11,  17,
#          0,   6,   8,   1,   3,   0,  25,   4,  36,   6,   3,   3,   7,
#          9,   0,   0,   8,  16,   3,   0,   3,   5,   5,  14,  15,  43,
#          6,  65,   0,  21, 106,  21,   8,  18,   9,   3,  13,   0,  10,
#         57,   4,  12,  29,   5,   1,   0,   0,   1,   1,   2,   2,  13,
#        108,   2,   8,  33,   3,  25,   7,  30,   0,   1,   0,   1,   0,
#          0,   2,  42,   6,   6,   2,  34,  26,  10,  10,   6,   1,  11,
#         39,   5,   1,   1,  94,  18,  75,   0,  31,  15, 100,   3,  15,
#          0,   1,  14,   2,   6,   1,   4,   2,   0,   1,   1,  11, 457,
#          2,   0,   3,   4,  16,   6,  10,  83,  60,  16,  30,   3,   5,
#          8,  13,  90,   0,   1,  11,   0,   0,   6,   7,  16,  57,  15,
#          0,  59,   2,   3,  39,  54,  14,   8,  25,   5,  13,  15,  18,
#         19,  11,   9,   0,   2,   0,  23,  12,  37,   3,   0,   3,  77]), array([2.48899750e-02, 5.93965312e-03, 2.48418921e+00, 3.99320051e+01,
#        0.00000000e+00, 8.48521875e-04, 1.13136250e-03, 1.41420312e-03,
#        2.96982656e-02, 2.52859519e-01, 2.30515109e-01, 5.65681250e-04,
#        5.06284719e-02, 3.95976875e-03, 6.22249375e-03, 8.48521875e-04,
#        5.65681250e-04, 5.65681250e-04, 7.80640125e-02, 1.88089016e-01,
#        1.66875969e-02, 1.69704375e-03, 1.06913756e-01, 2.27121022e-01,
#        1.69704375e-03, 2.04606908e+00, 8.76805937e-03, 1.07762278e-01,
#        6.50533437e-03, 4.62161581e-01, 2.08736381e-01, 3.76178031e-02,
#        5.06284719e-02, 9.05090000e-03, 7.91953750e-02, 6.16592562e-02,
#        2.53708041e-01, 1.78189594e-02, 1.52733937e-02, 0.00000000e+00,
#        2.03645250e-02, 8.76805937e-03, 7.91953750e-03, 1.24449875e-02,
#        1.68007331e-01, 1.47077125e-02, 2.41263053e-01, 5.60024437e-02,
#        2.82840625e-03, 7.38214031e-02, 6.91545328e-01, 3.67692812e-03,
#        4.52545000e-03, 4.52545000e-03, 2.40414531e-02, 3.35816674e+00,
#        6.22249375e-03, 5.65681250e-04, 3.95976875e-02, 1.75361187e-01,
#        5.82651687e-02, 2.26272500e-02, 2.34757719e-02, 2.65870187e-02,
#        2.82840625e-03, 3.39408750e-03, 1.44248719e-02, 1.97988437e-03,
#        3.87491656e-01, 7.07101562e-03, 9.54021428e-01, 2.00816844e-02,
#        4.52545000e-03, 9.33374062e-03, 1.55562344e+00, 6.50533437e-03,
#        1.40854631e-01, 1.92331625e-02, 9.64486531e-02, 8.48521875e-03,
#        1.15964656e-02, 2.37982102e+00, 2.82840625e-04, 0.00000000e+00,
#        8.48521875e-04, 8.76805937e-03, 5.09113125e-03, 2.85669031e-02,
#        6.56190250e-02, 5.30891853e-01, 5.09113125e-03, 4.80829062e-03,
#        4.80829062e-03, 1.82652819e+01, 7.12758375e-02, 3.95976875e-03,
#        1.13136250e-03, 1.09459322e-01, 5.17598344e-02, 4.07290500e-02,
#        2.03645250e-02, 7.35385625e-03, 1.34914978e+00, 2.06473656e-02,
#        8.48521875e-03, 2.80012219e-02, 3.87491656e-02, 5.65681250e-04,
#        1.41420312e-03, 7.07101562e-02, 1.41420312e-03, 7.35385625e-03,
#        2.34757719e-02, 3.93431309e-01, 5.37397187e-03, 1.13136250e-03,
#        1.27278281e-02, 2.82840625e-04, 1.18793062e-02, 1.04085350e-01,
#        2.26272500e-02, 7.91953750e-03, 5.65681250e-04, 2.20615687e-02,
#        6.22249375e-03, 6.50533437e-03, 1.13136250e-03, 4.78000656e-02,
#        1.51319734e-01, 1.69704375e-03, 4.21432531e-01, 3.67692812e-03,
#        2.82840625e-04, 2.26272500e-03, 2.82840625e-04, 1.64047562e-02,
#        1.14550453e-01, 3.39408750e-02, 3.56379187e-02, 3.67692812e-03,
#        4.86485875e-02, 2.17787281e-02, 2.91325844e-02, 2.82840625e-04,
#        8.48521875e-03, 2.57384969e-02, 2.82840625e-03, 4.52545000e-03,
#        0.00000000e+00, 2.85669031e-02, 3.67692812e-03, 9.30545656e-02,
#        5.20426750e-02, 8.48521875e-03, 3.11124687e-03, 7.91953750e-03,
#        6.19420969e-02, 5.65681250e-04, 0.00000000e+00, 1.81018000e-02,
#        5.43054000e-02, 2.82840625e-03, 2.82840625e-04, 6.78817500e-03,
#        9.61658125e-03, 3.33751937e-02, 1.66875969e-02, 2.65870187e-02,
#        9.57274095e+00, 3.67692812e-03, 7.41042437e-02, 0.00000000e+00,
#        1.21621469e-02, 1.79886637e-01, 1.18793062e-02, 3.39408750e-02,
#        3.05467875e-02, 1.27278281e-02, 6.78817500e-03, 3.36580344e-02,
#        5.65681250e-04, 2.03645250e-02, 1.14267612e-01, 1.38591906e-02,
#        1.75361187e-02, 1.64047562e-02, 2.88497437e-02, 4.80829062e-03,
#        2.82840625e-04, 5.65681250e-04, 1.69704375e-03, 4.52545000e-03,
#        7.35385625e-03, 5.09113125e-03, 2.65870187e-02, 2.76335291e-01,
#        7.07101562e-03, 5.71338062e-02, 8.45693469e-02, 6.50533437e-03,
#        1.44248719e-02, 1.75361187e-02, 4.32746156e-02, 2.82840625e-04,
#        5.09113125e-03, 0.00000000e+00, 2.82840625e-04, 1.69704375e-03,
#        0.00000000e+00, 5.65681250e-04, 7.21243594e-02, 1.86674812e-01,
#        3.39408750e-03, 1.18793062e-02, 3.62601681e-01, 8.31551437e-02,
#        5.93965312e-03, 3.64864406e-02, 1.04651031e-02, 1.41420312e-03,
#        1.97988437e-02, 2.20615687e-02, 4.24260937e-03, 1.04651031e-02,
#        3.05467875e-02, 1.33500775e-01, 3.67692812e-02, 2.12130469e-02,
#        0.00000000e+00, 6.93808053e-01, 9.10746812e-02, 1.98836959e-01,
#        1.47077125e-02, 1.38874747e-01, 0.00000000e+00, 3.95976875e-03,
#        1.17096019e-01, 1.13136250e-03, 2.48899750e-02, 3.95976875e-03,
#        1.24449875e-02, 5.65681250e-04, 0.00000000e+00, 2.26272500e-03,
#        8.48521875e-04, 6.50533437e-03, 1.03491385e+00, 3.67692812e-03,
#        2.82840625e-03, 1.21621469e-02, 3.95976875e-03, 3.22438312e-02,
#        3.39408750e-03, 2.10433425e-01, 2.34757719e-02, 1.02388306e-01,
#        3.67692812e-02, 2.54556562e-02, 1.97988437e-03, 6.22249375e-03,
#        4.80829062e-03, 2.63041781e-02, 1.12909977e+00, 0.00000000e+00,
#        5.65681250e-04, 1.50188372e-01, 8.48521875e-04, 0.00000000e+00,
#        9.05090000e-03, 1.97988437e-02, 3.30923531e-02, 1.28353076e+00,
#        1.69704375e-02, 5.65681250e-04, 6.67503875e-02, 5.09113125e-03,
#        3.39408750e-03, 5.60024437e-02, 1.38874747e-01, 3.62036000e-02,
#        9.61658125e-03, 1.41420312e-02, 3.67692812e-02, 3.50722375e-02,
#        6.47705031e-02, 5.23255156e-02, 6.13764156e-02, 1.25581237e-01,
#        3.90320062e-02, 0.00000000e+00, 7.07101562e-03, 1.69704375e-03,
#        1.16077792e+00, 6.50533437e-02, 2.23161253e-01, 2.57384969e-02,
#        5.65681250e-04, 5.65681250e-03, 2.17787281e-02])]

# %% [markdown]
# ## Plot the line
# In order to make the data more acessible, the data can be plotted

# %%
# %pylab inline --no-import-all 

division = divide_data_in_portions(data_set)
sorted_division = np.sort(division[3])


plt.scatter(range(len(sorted_division)), sorted_division)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# There are in total 353556 citations in this data
# Found 299 unique variables
# 0
